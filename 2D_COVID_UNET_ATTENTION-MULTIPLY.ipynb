# %%
import os
import zipfile
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
import os
import nibabel as nib
from scipy import ndimage
from sklearn import preprocessing
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Add, Rescaling , Multiply, SeparableConv2D, Conv2D, Conv1D, Subtract, Conv2DTranspose, UpSampling2D, Dropout, BatchNormalization, Dense, Activation, concatenate, PReLU , UpSampling2D, GlobalAveragePooling2D, AveragePooling2D, Lambda, Concatenate, LeakyReLU, Reshape, Permute,PReLU, Flatten, MaxPooling2D
import tensorflow.keras.backend as K
import os
import cv2
from tqdm import tqdm
import gc
from keras_unet_collection import models
#import memory_saving_gradients as mg

#tf.__dict__["gradients"] = mg.gradients_memory
# from tensorflow.python.ops import gradients as tf_gradients
# tf_gradients.gradients = mg.gradients_memory

# %%
from tensorflow.keras import mixed_precision
# policy = mixed_precision.Policy('mixed_float16')
# mixed_precision.set_global_policy(policy)
# print('Compute dtype: %s' % policy.compute_dtype)
# print('Variable dtype: %s' % policy.variable_dtype)
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)

# %%
Train_Image = "SEGMENTATION DATASET IMAGES 2/Train/Images/"
Train_Mask = "SEGMENTATION DATASET IMAGES 2/Train/Masks/"
Valid_Image = "SEGMENTATION DATASET IMAGES 2/Valid/Images/"
Valid_Mask = "SEGMENTATION DATASET IMAGES 2/Valid/Masks/"

# %%
def preprocess(image):
  return image/255.
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# train_datagen = ImageDataGenerator(rotation_range=60,
#                                    horizontal_flip = True, vertical_flip = True
#                                    , preprocessing_function=preprocess)
train_datagen = ImageDataGenerator(preprocessing_function=preprocess)
seed = 1000
batch_size = 8
train_image_generator = train_datagen.flow_from_directory(Train_Image, seed=seed, batch_size= batch_size, shuffle = True,  class_mode = None)

train_mask_generator = train_datagen.flow_from_directory(Train_Mask, seed=seed, batch_size = batch_size, shuffle = True, color_mode = "grayscale", class_mode = None)

train_generator = zip(train_image_generator, train_mask_generator)

valid_datagen = ImageDataGenerator(preprocessing_function=preprocess)

val_image_generator = valid_datagen.flow_from_directory(Valid_Image, batch_size= 767, shuffle = False)

val_mask_generator = valid_datagen.flow_from_directory(Valid_Mask, batch_size = 767, shuffle = False, color_mode = "grayscale")

val_generator = zip(val_image_generator, val_mask_generator)
# Out:
# Found 2234 images belonging to 1 classes.
# Found 2234 images belonging to 1 classes.
# Found 559 images belonging to 1 classes.
# Found 559 images belonging to 1 classes.

# %%
Valid_Images,Valid_Masks = next(val_generator)
Valid_Images = Valid_Images[0]
Valid_Masks = Valid_Masks[0]

# %%
import random

def jaccard_score(y_true, y_pred, smooth=1e-6):
    """Jaccard distance for semantic segmentation.
    Also known as the intersection-over-union loss.
    This loss is useful when you have unbalanced numbers of pixels within an image
    because it gives all classes equal weight. However, it is not the defacto
    standard for image segmentation.
    For example, assume you are trying to predict if
    each pixel is cat, dog, or background.
    You have 80% background pixels, 10% dog, and 10% cat.
    If the model predicts 100% background
    should it be be 80% right (as with categorical cross entropy)
    or 30% (with this loss)?
    The loss has been modified to have a smooth gradient as it converges on zero.
    This has been shifted so it converges on 0 and is smoothed to avoid exploding
    or disappearing gradient.
    Jaccard = (|X & Y|)/ (|X|+ |Y| - |X & Y|)
            = sum(|A*B|)/(sum(|A|)+sum(|B|)-sum(|A*B|))
    # Arguments
        y_true: The ground truth tensor.
        y_pred: The predicted tensor
        smooth: Smoothing factor. Default is 100.
    # Returns
        The Jaccard distance between the two tensors.
    # References
        - [What is a good evaluation measure for semantic segmentation?](
           http://www.bmva.org/bmvc/2013/Papers/paper0032/paper0032.pdf)
    """
    axis = -1
    y_pred = K.flatten(y_pred)
    y_true = K.flatten(y_true)
    intersection = K.sum(K.abs(y_true * y_pred), axis=axis)
    sum_ = K.sum(K.abs(y_true) + K.abs(y_pred), axis=axis)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac


def jaccard_distance (y_true, y_pred, smooth=1):
    return 1 - jaccard_score(y_true, y_pred, smooth=1e-6) * smooth

# def dice_coef(y_true, y_pred, smooth=1e-6):
#     """
#     Dice = (2*|X & Y|)/ (|X|+ |Y|)
#          =  2*sum(|A*B|)/(sum(A^2)+sum(B^2))
#     ref: https://arxiv.org/pdf/1606.04797v1.pdf
#     """
#     intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
#     return (2. * intersection + smooth) / (K.sum(K.square(y_true),-1) + K.sum(K.square(y_pred),-1) + smooth)
def dice_coef(y_true, y_pred, epsilon=0.00001):
    """
    Dice = (2*|X & Y|)/ (|X|+ |Y|)
         =  2*sum(|A*B|)/(sum(A^2)+sum(B^2))
    ref: https://arxiv.org/pdf/1606.04797v1.pdf
    
    """
    axis = -1
    y_pred = K.flatten(y_pred)
    y_true = K.flatten(y_true)
    dice_numerator = 2. * K.sum(y_true * y_pred, axis=axis) + epsilon
    dice_denominator = K.sum(y_true*y_true, axis=axis) + K.sum(y_pred*y_pred, axis=axis) + epsilon
    return K.mean((dice_numerator)/(dice_denominator))


def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)



ALPHA = 0.3
BETA = 0.7
GAMMA = 1

def FocalTverskyLoss(y_true, y_pred, alpha=ALPHA, beta=BETA, gamma=GAMMA, smooth=1e-6):
    
        #flatten label and prediction tensors
        y_pred = K.flatten(y_pred)
        y_true = K.flatten(y_true)
        axis = -1
        #True Positives, False Positives & False Negatives
        TP = K.sum(y_true * y_pred, axis=axis)
        FP = K.sum(y_true * (1-y_pred), axis=axis)
        FN = K.sum((1-y_true) * y_pred, axis=axis)
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        FocalTversky = K.pow((1 - Tversky), gamma)
        
        return FocalTversky


def Tversky (y_true, y_pred, smooth=1e-6):
            #flatten label and prediction tensors
        alpha = .3
        beta = 1 - alpha 
        y_pred = K.flatten(y_pred)
        y_true = K.flatten(y_true)
        
        #True Positives, False Positives & False Negatives
        TP = K.sum((y_pred * y_true))
        FP = K.sum(((1-y_true) * y_pred))
        FN = K.sum((y_true * (1-y_pred)))
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        return Tversky
    
def Tversky_loss (y_true, y_pred, smooth=1e-6):
    return 1 - Tversky (y_true, y_pred, smooth)

def Tversky_crossentropy(y_true, y_pred):
    Tversky = K.pow(Tversky_loss(y_true, y_pred),3/4)
    crossentropy = K.binary_crossentropy(y_true, y_pred)
    crossentropy = K.mean(crossentropy)
    
    return Tversky + crossentropy
def DiceBCELoss(y_true, y_pred, smooth=1e-6):    
       
    #flatten label and prediction tensors
    #y_pred = K.flatten(y_pred)
    #y_true = K.flatten(y_true)
    
    BCE =  K.binary_crossentropy(y_true, y_pred)
    intersection = K.sum(K.abs(y_true * y_pred), axis=(0,1,2,3))  
    dice_loss = 1 - (2*intersection + smooth) / (K.sum(y_true) + K.sum(y_pred) + smooth)
    Dice_BCE = BCE + dice_loss
    
    return Dice_BCE




def euclidean_distance_loss(y_true, y_pred):
    """
    Euclidean distance loss
    https://en.wikipedia.org/wiki/Euclidean_distance
    :param y_true: TensorFlow tensor
    :param y_pred: TensorFlow tensor of the same shape as y_true
    :return: float
    """
    return K.sqrt(K.sum(K.square(y_pred - y_true), axis=-1))


def binary_recall_specificity(y_true, y_pred, recall_weight, spec_weight):
    y_pred = K.flatten(y_pred)
    y_true = K.flatten(y_true)
    
    TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    TN = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    FP = K.sum(K.round(K.clip((1 - y_true) * y_pred, 0, 1)))
    FN = K.sum(K.round(K.clip(y_true * (1 - y_pred), 0, 1)))

    # Converted as Keras Tensors


    specificity = TN / (TN + FP + K.epsilon())
    recall = TP / (TP + FN + K.epsilon())

    return 1.0 - (recall_weight*recall + spec_weight*specificity)

def custom_loss(recall_weight, spec_weight):

    def recall_spec_loss(y_true, y_pred):
        return binary_recall_specificity(y_true, y_pred, recall_weight, spec_weight)

    # Returns the (y_true, y_pred) loss function
    return recall_spec_loss


def mix_loss(y_true, y_pred):
    FTC = FocalTverskyLoss(y_true, y_pred)
    DCB = DiceBCELoss(y_true, y_pred)
    return FTC + DCB

# %%
# weight: weighted tensor(same shape with mask image)
def weighted_bce_loss(y_true, y_pred, weight):
    # avoiding overflow
    epsilon = 1e-7
    y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
    logit_y_pred = K.log(y_pred / (1. - y_pred))
    
    # https://www.tensorflow.org/api_docs/python/tf/nn/weighted_cross_entropy_with_logits
    loss = (1. - y_true) * logit_y_pred + (1. + (weight - 1.) * y_true) * \
    (K.log(1. + K.exp(-K.abs(logit_y_pred))) + K.maximum(-logit_y_pred, 0.))
    return K.sum(loss) / K.sum(weight)

def weighted_dice_loss(y_true, y_pred, weight):
    smooth = 1e-6
    w, m1, m2 = weight * weight, y_true, y_pred
    intersection = (m1 * m2)
    score = (2. * K.sum(w * intersection) + smooth) / (K.sum(w * m1) + K.sum(w * m2) + smooth)
    loss = 1. - K.sum(score)
    return loss

def weighted_bce_dice_loss(y_true, y_pred):
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')
    # if we want to get same size of output, kernel size must be odd number
    averaged_mask = K.pool2d(
            y_true, pool_size=(11, 11), strides=(1, 1), padding='same', pool_mode='avg')
    border = K.cast(K.greater(averaged_mask, 0.005), 'float32') * K.cast(K.less(averaged_mask, 0.995), 'float32')
    weight = K.ones_like(averaged_mask)
    w0 = K.sum(weight)
    weight += border * 2
    w1 = K.sum(weight)
    weight *= (w0 / w1)
    loss = weighted_bce_loss(y_true, y_pred, weight) + \
    weighted_dice_loss(y_true, y_pred, weight)
    return loss



def SSIM (y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val = 1.0) 

def SSIM_LOSS (y_true, y_pred):
    return (1 - SSIM(y_true,y_pred))


def f1_score(y_true, y_pred):
    y_pred = K.flatten(y_pred)
    y_true = K.flatten(y_true)
    
    TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    TN = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    FP = K.sum(K.round(K.clip((1 - y_true) * y_pred, 0, 1)))
    FN = K.sum(K.round(K.clip(y_true * (1 - y_pred), 0, 1)))

    # Converted as Keras Tensors


    return (TP/(TP+(0.5 * (FP+FN))))

from scipy.ndimage import distance_transform_edt as distance


def calc_dist_map(seg):
    res = np.zeros_like(seg)
    posmask = seg.astype(np.bool)

    if posmask.any():
        negmask = ~posmask
        res = distance(negmask) * negmask - (distance(posmask) - 1) * posmask

    return res


def calc_dist_map_batch(y_true):
    y_true_numpy = y_true.numpy()
    return np.array([calc_dist_map(y)
                     for y in y_true_numpy]).reshape(y_true.shape).astype(np.float32)


def surface_loss_keras(y_true, y_pred):
    y_true_dist_map = tf.py_function(func=calc_dist_map_batch,
                                     inp=[y_true],
                                     Tout=tf.float32)
    multipled = y_pred * y_true_dist_map
    return K.mean(multipled)

def Combo_loss(targets, inputs, eps=1e-9):
        ALPHA = 0.5# < 0.5 penalises FP more, > 0.5 penalises FN         more
        CE_RATIO = 0.5 #weighted contribution of modified CE loss compared to Dice loss
        smooth = 1
        targets = K.flatten(targets)
        inputs = K.flatten(inputs)
                
        intersection = K.sum(targets * inputs)
        dice = (2. * intersection + smooth) / (K.sum(targets) + K.sum(inputs) + smooth)
        inputs = K.clip(inputs, eps, 1.0 - eps)
        out = - (ALPHA * ((targets * K.log(inputs)) + ((1 - ALPHA) * (1.0 - targets) * K.log(1.0 - inputs))))
        weighted_ce = K.mean(out, axis=-1)
        combo = (CE_RATIO * weighted_ce) - ((1 - CE_RATIO) * dice)
                          
def wasserstein_loss(y_true, y_pred):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    return K.mean(y_true * y_pred) 



def log_cosh_dice(y_true, y_pred):
    x = dice_coef_loss(y_true, y_pred)
    cosh_x = (K.exp(x) + K.exp(-x))/2
    loss = K.log(cosh_x)
    return loss

def mix_loss(y_true, y_pred):
    FTC = Tversky_crossentropy(y_true, y_pred)
    SSIM = SSIM_LOSS(y_true, y_pred)
    SL = surface_loss_keras(y_true, y_pred)
    return  FTC + SL * .1 + SSIM * 1.5

# %%
def get_model():
    model = models.att_unet_2d((None, None, 3), filter_num=[64, 128, 256, 512, 1024], n_labels=1, 
                           stack_num_down=2, stack_num_up=2, activation='ReLU', 
                           atten_activation='ReLU', attention='multiply', output_activation='Sigmoid', 
                           batch_norm=True, pool=False, unpool=False, 
                           backbone='VGG16', weights='imagenet', 
                           freeze_backbone=True, freeze_batch_norm=True, 
                           name='attunet')
    return model

# %%
model = get_model()
model.compile(optimizer="adam", loss= FocalTverskyLoss,  metrics = ["accuracy",dice_coef, jaccard_score,
                                                                       tf.keras.metrics.Precision(),tf.keras.metrics.Recall() ])

model.summary()
lr = 1e-3
K.set_value(model.optimizer.lr,lr)
# Out:
# c:\users\boude\appdata\local\programs\python\python38\lib\site-packages\keras_unet_collection\_backbone_zoo.py:45: UserWarning:
#
# Backbone VGG16 does not use batch norm, but other layers received batch_norm=True
#   warnings.warn(param_mismatch);
# Model: "attunet_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  VGG16_backbone (Functional)    [(None, None, None,  14714688    ['input_1[0][0]']
#                                  64),
#                                  (None, None, None,
#                                  128),
#                                  (None, None, None,
#                                  256),
#                                  (None, None, None,
#                                  512),
#                                  (None, None, None,
#                                  512)]
#
#  attunet_up0_decode_trans_conv   (None, None, None,   2359808    ['VGG16_backbone[0][4]']
#  (Conv2DTranspose)              512)
#
#  attunet_up0_decode_bn (BatchNo  (None, None, None,   2048       ['attunet_up0_decode_trans_conv[0
#  rmalization)                   512)                             ][0]']
#
#  attunet_up0_decode_activation   (None, None, None,   0          ['attunet_up0_decode_bn[0][0]']
#  (ReLU)                         512)
#
#  attunet_up0_att_theta_x (Conv2  (None, None, None,   131328     ['VGG16_backbone[0][3]']
#  D)                             256)
#
#  attunet_up0_att_phi_g (Conv2D)  (None, None, None,   131328     ['attunet_up0_decode_activation[0
#                                 256)                             ][0]']
#
#  attunet_up0_att_add (Multiply)  (None, None, None,   0          ['attunet_up0_att_theta_x[0][0]',
#                                 256)                              'attunet_up0_att_phi_g[0][0]']
#
#  attunet_up0_att_activation (Re  (None, None, None,   0          ['attunet_up0_att_add[0][0]']
#  LU)                            256)
#
#  attunet_up0_att_psi_f (Conv2D)  (None, None, None,   257        ['attunet_up0_att_activation[0][0
#                                 1)                               ]']
#
#  attunet_up0_att_sigmoid (Activ  (None, None, None,   0          ['attunet_up0_att_psi_f[0][0]']
#  ation)                         1)
#
#  attunet_up0_att_masking (Multi  (None, None, None,   0          ['VGG16_backbone[0][3]',
#  ply)                           512)                              'attunet_up0_att_sigmoid[0][0]']
#
#  attunet_up0_concat (Concatenat  (None, None, None,   0          ['attunet_up0_decode_activation[0
#  e)                             1024)                            ][0]',
#                                                                   'attunet_up0_att_masking[0][0]']
#
#  attunet_up0_conv_after_concat_  (None, None, None,   4718592    ['attunet_up0_concat[0][0]']
#  0 (Conv2D)                     512)
#
#  attunet_up0_conv_after_concat_  (None, None, None,   2048       ['attunet_up0_conv_after_concat_0
#  0_bn (BatchNormalization)      512)                             [0][0]']
#
#  attunet_up0_conv_after_concat_  (None, None, None,   0          ['attunet_up0_conv_after_concat_0
#  0_activation (ReLU)            512)                             _bn[0][0]']
#
#  attunet_up0_conv_after_concat_  (None, None, None,   2359296    ['attunet_up0_conv_after_concat_0
#  1 (Conv2D)                     512)                             _activation[0][0]']
#
#  attunet_up0_conv_after_concat_  (None, None, None,   2048       ['attunet_up0_conv_after_concat_1
#  1_bn (BatchNormalization)      512)                             [0][0]']
#
#  attunet_up0_conv_after_concat_  (None, None, None,   0          ['attunet_up0_conv_after_concat_1
#  1_activation (ReLU)            512)                             _bn[0][0]']
#
#  attunet_up1_decode_trans_conv   (None, None, None,   1179904    ['attunet_up0_conv_after_concat_1
#  (Conv2DTranspose)              256)                             _activation[0][0]']
#
#  attunet_up1_decode_bn (BatchNo  (None, None, None,   1024       ['attunet_up1_decode_trans_conv[0
#  rmalization)                   256)                             ][0]']
#
#  attunet_up1_decode_activation   (None, None, None,   0          ['attunet_up1_decode_bn[0][0]']
#  (ReLU)                         256)
#
#  attunet_up1_att_theta_x (Conv2  (None, None, None,   32896      ['VGG16_backbone[0][2]']
#  D)                             128)
#
#  attunet_up1_att_phi_g (Conv2D)  (None, None, None,   32896      ['attunet_up1_decode_activation[0
#                                 128)                             ][0]']
#
#  attunet_up1_att_add (Multiply)  (None, None, None,   0          ['attunet_up1_att_theta_x[0][0]',
#                                 128)                              'attunet_up1_att_phi_g[0][0]']
#
#  attunet_up1_att_activation (Re  (None, None, None,   0          ['attunet_up1_att_add[0][0]']
#  LU)                            128)
#
#  attunet_up1_att_psi_f (Conv2D)  (None, None, None,   129        ['attunet_up1_att_activation[0][0
#                                 1)                               ]']
#
#  attunet_up1_att_sigmoid (Activ  (None, None, None,   0          ['attunet_up1_att_psi_f[0][0]']
#  ation)                         1)
#
#  attunet_up1_att_masking (Multi  (None, None, None,   0          ['VGG16_backbone[0][2]',
#  ply)                           256)                              'attunet_up1_att_sigmoid[0][0]']
#
#  attunet_up1_concat (Concatenat  (None, None, None,   0          ['attunet_up1_decode_activation[0
#  e)                             512)                             ][0]',
#                                                                   'attunet_up1_att_masking[0][0]']
#
#  attunet_up1_conv_after_concat_  (None, None, None,   1179648    ['attunet_up1_concat[0][0]']
#  0 (Conv2D)                     256)
#
#  attunet_up1_conv_after_concat_  (None, None, None,   1024       ['attunet_up1_conv_after_concat_0
#  0_bn (BatchNormalization)      256)                             [0][0]']
#
#  attunet_up1_conv_after_concat_  (None, None, None,   0          ['attunet_up1_conv_after_concat_0
#  0_activation (ReLU)            256)                             _bn[0][0]']
#
#  attunet_up1_conv_after_concat_  (None, None, None,   589824     ['attunet_up1_conv_after_concat_0
#  1 (Conv2D)                     256)                             _activation[0][0]']
#
#  attunet_up1_conv_after_concat_  (None, None, None,   1024       ['attunet_up1_conv_after_concat_1
#  1_bn (BatchNormalization)      256)                             [0][0]']
#
#  attunet_up1_conv_after_concat_  (None, None, None,   0          ['attunet_up1_conv_after_concat_1
#  1_activation (ReLU)            256)                             _bn[0][0]']
#
#  attunet_up2_decode_trans_conv   (None, None, None,   295040     ['attunet_up1_conv_after_concat_1
#  (Conv2DTranspose)              128)                             _activation[0][0]']
#
#  attunet_up2_decode_bn (BatchNo  (None, None, None,   512        ['attunet_up2_decode_trans_conv[0
#  rmalization)                   128)                             ][0]']
#
#  attunet_up2_decode_activation   (None, None, None,   0          ['attunet_up2_decode_bn[0][0]']
#  (ReLU)                         128)
#
#  attunet_up2_att_theta_x (Conv2  (None, None, None,   8256       ['VGG16_backbone[0][1]']
#  D)                             64)
#
#  attunet_up2_att_phi_g (Conv2D)  (None, None, None,   8256       ['attunet_up2_decode_activation[0
#                                 64)                              ][0]']
#
#  attunet_up2_att_add (Multiply)  (None, None, None,   0          ['attunet_up2_att_theta_x[0][0]',
#                                 64)                               'attunet_up2_att_phi_g[0][0]']
#
#  attunet_up2_att_activation (Re  (None, None, None,   0          ['attunet_up2_att_add[0][0]']
#  LU)                            64)
#
#  attunet_up2_att_psi_f (Conv2D)  (None, None, None,   65         ['attunet_up2_att_activation[0][0
#                                 1)                               ]']
#
#  attunet_up2_att_sigmoid (Activ  (None, None, None,   0          ['attunet_up2_att_psi_f[0][0]']
#  ation)                         1)
#
#  attunet_up2_att_masking (Multi  (None, None, None,   0          ['VGG16_backbone[0][1]',
#  ply)                           128)                              'attunet_up2_att_sigmoid[0][0]']
#
#  attunet_up2_concat (Concatenat  (None, None, None,   0          ['attunet_up2_decode_activation[0
#  e)                             256)                             ][0]',
#                                                                   'attunet_up2_att_masking[0][0]']
#
#  attunet_up2_conv_after_concat_  (None, None, None,   294912     ['attunet_up2_concat[0][0]']
#  0 (Conv2D)                     128)
#
#  attunet_up2_conv_after_concat_  (None, None, None,   512        ['attunet_up2_conv_after_concat_0
#  0_bn (BatchNormalization)      128)                             [0][0]']
#
#  attunet_up2_conv_after_concat_  (None, None, None,   0          ['attunet_up2_conv_after_concat_0
#  0_activation (ReLU)            128)                             _bn[0][0]']
#
#  attunet_up2_conv_after_concat_  (None, None, None,   147456     ['attunet_up2_conv_after_concat_0
#  1 (Conv2D)                     128)                             _activation[0][0]']
#
#  attunet_up2_conv_after_concat_  (None, None, None,   512        ['attunet_up2_conv_after_concat_1
#  1_bn (BatchNormalization)      128)                             [0][0]']
#
#  attunet_up2_conv_after_concat_  (None, None, None,   0          ['attunet_up2_conv_after_concat_1
#  1_activation (ReLU)            128)                             _bn[0][0]']
#
#  attunet_up3_decode_trans_conv   (None, None, None,   73792      ['attunet_up2_conv_after_concat_1
#  (Conv2DTranspose)              64)                              _activation[0][0]']
#
#  attunet_up3_decode_bn (BatchNo  (None, None, None,   256        ['attunet_up3_decode_trans_conv[0
#  rmalization)                   64)                              ][0]']
#
#  attunet_up3_decode_activation   (None, None, None,   0          ['attunet_up3_decode_bn[0][0]']
#  (ReLU)                         64)
#
#  attunet_up3_att_theta_x (Conv2  (None, None, None,   2080       ['VGG16_backbone[0][0]']
#  D)                             32)
#
#  attunet_up3_att_phi_g (Conv2D)  (None, None, None,   2080       ['attunet_up3_decode_activation[0
#                                 32)                              ][0]']
#
#  attunet_up3_att_add (Multiply)  (None, None, None,   0          ['attunet_up3_att_theta_x[0][0]',
#                                 32)                               'attunet_up3_att_phi_g[0][0]']
#
#  attunet_up3_att_activation (Re  (None, None, None,   0          ['attunet_up3_att_add[0][0]']
#  LU)                            32)
#
#  attunet_up3_att_psi_f (Conv2D)  (None, None, None,   33         ['attunet_up3_att_activation[0][0
#                                 1)                               ]']
#
#  attunet_up3_att_sigmoid (Activ  (None, None, None,   0          ['attunet_up3_att_psi_f[0][0]']
#  ation)                         1)
#
#  attunet_up3_att_masking (Multi  (None, None, None,   0          ['VGG16_backbone[0][0]',
#  ply)                           64)                               'attunet_up3_att_sigmoid[0][0]']
#
#  attunet_up3_concat (Concatenat  (None, None, None,   0          ['attunet_up3_decode_activation[0
#  e)                             128)                             ][0]',
#                                                                   'attunet_up3_att_masking[0][0]']
#
#  attunet_up3_conv_after_concat_  (None, None, None,   73728      ['attunet_up3_concat[0][0]']
#  0 (Conv2D)                     64)
#
#  attunet_up3_conv_after_concat_  (None, None, None,   256        ['attunet_up3_conv_after_concat_0
#  0_bn (BatchNormalization)      64)                              [0][0]']
#
#  attunet_up3_conv_after_concat_  (None, None, None,   0          ['attunet_up3_conv_after_concat_0
#  0_activation (ReLU)            64)                              _bn[0][0]']
#
#  attunet_up3_conv_after_concat_  (None, None, None,   36864      ['attunet_up3_conv_after_concat_0
#  1 (Conv2D)                     64)                              _activation[0][0]']
#
#  attunet_up3_conv_after_concat_  (None, None, None,   256        ['attunet_up3_conv_after_concat_1
#  1_bn (BatchNormalization)      64)                              [0][0]']
#
#  attunet_up3_conv_after_concat_  (None, None, None,   0          ['attunet_up3_conv_after_concat_1
#  1_activation (ReLU)            64)                              _bn[0][0]']
#
#  attunet_output (Conv2D)        (None, None, None,   65          ['attunet_up3_conv_after_concat_1
#                                 1)                               _activation[0][0]']
#
#  attunet_output_activation (Act  (None, None, None,   0          ['attunet_output[0][0]']
#  ivation)                       1)
#
# ==================================================================================================
# Total params: 28,384,741
# Trainable params: 13,664,293
# Non-trainable params: 14,720,448
# __________________________________________________________________________________________________

# %%
import matplotlib.pyplot as plt
def visualize(image_batch, mask_batch=None, pred_batch=None, num_samples = None):
    num_classes = mask_batch.shape[-1] if mask_batch is not None else 0
    fix, ax = plt.subplots(num_classes + 1, num_samples, figsize=(num_samples * 2, (num_classes + 1) * 2))

    for i in range(num_samples):
        ax_image = ax[0, i] if num_classes > 0 else ax[i]
        ax_image.imshow(image_batch[i,:,:,0], cmap='gray')
        ax_image.set_xticks([]) 
        ax_image.set_yticks([])
        
        if mask_batch is not None:
            for j in range(num_classes):
                if pred_batch is None:
                    mask_to_show = mask_batch[i,:,:,j]
                else:
                    mask_to_show = np.zeros(shape=(*mask_batch.shape[1:-1], 3)) 
                    mask_to_show[..., 0] = pred_batch[i,:,:,j] > 0.5
                    mask_to_show[..., 1] = mask_batch[i,:,:,j]
                ax[j + 1, i].imshow(mask_to_show, vmin=0, vmax=1, cmap='gray')
                ax[j + 1, i].set_xticks([]) 
                ax[j + 1, i].set_yticks([]) 

    plt.tight_layout()
    plt.show()

# %%
#model.load_weights("Segmentation GAN WEIGHTS/2D/ATT UNET/UNET_ATT_MULTIPLY.h5")
val = model.evaluate(Valid_Images, Valid_Masks, batch_size = 16, verbose = 1)
# Out:
# 35/35 [==============================] - 13s 194ms/step - loss: 0.9566 - accuracy: 0.4588 - dice_coef: 0.1049 - jaccard_score: 0.0302 - precision: 0.0346 - recall: 0.5020

# %%
x, y = Valid_Images[400:408], Valid_Masks[400:408]
preds = model.predict_on_batch(x)
visualize(x,y, num_samples=8)

visualize(x,preds, num_samples=8)

# %%
import os
os._exit(00)

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "Segmentation GAN WEIGHTS/2D/UNET_ATT_MULTIPLY.h5", monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch')

# %%
TB = tf.keras.callbacks.TensorBoard(
    log_dir='logs_UNET_ATT_MULTIPLY',
    histogram_freq=1,
    write_graph=False,
    write_images=False,
    write_steps_per_second=False,
    update_freq='epoch',
    profile_batch=0,
    embeddings_freq=0,
    embeddings_metadata=None
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=25,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)

# %%
#generator.load_weights("/content/drive/MyDrive/SEP SEGMENTATION PROJECT/Segmentation GAN WEIGHTS/UNET_NRC2D_SEP.h5")
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=10,
    verbose=1)
batch_size = 8
history = model.fit(train_generator, verbose = 1, epochs = 150,
          validation_data = [Valid_Images, Valid_Masks] , callbacks = [checkpoint,reduce_lr,tf.keras.callbacks.TerminateOnNaN(), early_stopping, TB],
          steps_per_epoch = (2234//batch_size)//16, initial_epoch = 0)
# Out:
# Epoch 1/150
# 48/48 [==============================] - ETA: 0s - loss: 0.6799 - accuracy: 0.9490 - dice_coef: 0.5658 - jaccard_score: 0.2382 - precision: 0.3386 - recall: 0.7014
# Epoch 1: val_loss improved from inf to 0.94656, saving model to Segmentation GAN WEIGHTS/2D\UNET_ATT_MULTIPLY.h5
# 48/48 [==============================] - 45s 794ms/step - loss: 0.6799 - accuracy: 0.9490 - dice_coef: 0.5658 - jaccard_score: 0.2382 - precision: 0.3386 - recall: 0.7014 - val_loss: 0.9466 - val_accuracy: 0.2059 - val_dice_coef: 0.0741 - val_jaccard_score: 0.0378 - val_precision: 0.0451 - val_recall: 1.0000 - lr: 0.0010
# Epoch 2/150
# 48/48 [==============================] - ETA: 0s - loss: 0.4239 - accuracy: 0.9793 - dice_coef: 0.7091 - jaccard_score: 0.4325 - precision: 0.7588 - recall: 0.6020
# Epoch 2: val_loss improved from 0.94656 to 0.86112, saving model to Segmentation GAN WEIGHTS/2D\UNET_ATT_MULTIPLY.h5
# 48/48 [==============================] - 29s 618ms/step - loss: 0.4239 - accuracy: 0.9793 - dice_coef: 0.7091 - jaccard_score: 0.4325 - precision: 0.7588 - recall: 0.6020 - val_loss: 0.8611 - val_accuracy: 0.7442 - val_dice_coef: 0.2001 - val_jaccard_score: 0.1011 - val_precision: 0.1274 - val_recall: 0.9665 - lr: 0.0010
# Epoch 3/150
# 48/48 [==============================] - ETA: 0s - loss: 0.3409 - accuracy: 0.9789 - dice_coef: 0.6929 - jaccard_score: 0.4776 - precision: 0.8003 - recall: 0.5398
# Epoch 3: val_loss improved from 0.86112 to 0.77955, saving model to Segmentation GAN WEIGHTS/2D\UNET_ATT_MULTIPLY.h5
# 48/48 [==============================] - 28s 595ms/step - loss: 0.3409 - accuracy: 0.9789 - dice_coef: 0.6929 - jaccard_score: 0.4776 - precision: 0.8003 - recall: 0.5398 - val_loss: 0.7795 - val_accuracy: 0.8855 - val_dice_coef: 0.3428 - val_jaccard_score: 0.1649 - val_precision: 0.2508 - val_recall: 0.9335 - lr: 0.0010
# Epoch 4/150
# 48/48 [==============================] - ETA: 0s - loss: 0.2960 - accuracy: 0.9805 - dice_coef: 0.7169 - jaccard_score: 0.5218 - precision: 0.8208 - recall: 0.5606
# Epoch 4: val_loss improved from 0.77955 to 0.75939, saving model to Segmentation GAN WEIGHTS/2D\UNET_ATT_MULTIPLY.h5
# 48/48 [==============================] - 26s 549ms/step - loss: 0.2960 - accuracy: 0.9805 - dice_coef: 0.7169 - jaccard_score: 0.5218 - precision: 0.8208 - recall: 0.5606 - val_loss: 0.7594 - val_accuracy: 0.9222 - val_dice_coef: 0.4181 - val_jaccard_score: 0.1801 - val_precision: 0.3263 - val_recall: 0.8442 - lr: 0.0010
# Epoch 5/150
# 48/48 [==============================] - ETA: 0s - loss: 0.2714 - accuracy: 0.9815 - dice_coef: 0.7246 - jaccard_score: 0.5378 - precision: 0.8560 - recall: 0.5472
# Epoch 5: val_loss improved from 0.75939 to 0.63417, saving model to Segmentation GAN WEIGHTS/2D\UNET_ATT_MULTIPLY.h5
# 48/48 [==============================] - 25s 529ms/step - loss: 0.2714 - accuracy: 0.9815 - dice_coef: 0.7246 - jaccard_score: 0.5378 - precision: 0.8560 - recall: 0.5472 - val_loss: 0.6342 - val_accuracy: 0.9347 - val_dice_coef: 0.4817 - val_jaccard_score: 0.2822 - val_precision: 0.3739 - val_recall: 0.8411 - lr: 0.0010
# Epoch 6/150
# 48/48 [==============================] - ETA: 0s - loss: 0.2474 - accuracy: 0.9830 - dice_coef: 0.7445 - jaccard_score: 0.5682 - precision: 0.8690 - recall: 0.5662
# Epoch 6: val_loss improved from 0.63417 to 0.49343, saving model to Segmentation GAN WEIGHTS/2D\UNET_ATT_MULTIPLY.h5
# 48/48 [==============================] - 25s 514ms/step - loss: 0.2474 - accuracy: 0.9830 - dice_coef: 0.7445 - jaccard_score: 0.5682 - precision: 0.8690 - recall: 0.5662 - val_loss: 0.4934 - val_accuracy: 0.9562 - val_dice_coef: 0.5820 - val_jaccard_score: 0.4024 - val_precision: 0.5017 - val_recall: 0.8293 - lr: 0.0010
# Epoch 7/150
# 48/48 [==============================] - ETA: 0s - loss: 0.2338 - accuracy: 0.9825 - dice_coef: 0.7529 - jaccard_score: 0.5806 - precision: 0.8803 - recall: 0.5753
# Epoch 7: val_loss improved from 0.49343 to 0.37108, saving model to Segmentation GAN WEIGHTS/2D\UNET_ATT_MULTIPLY.h5
# 48/48 [==============================] - 16s 332ms/step - loss: 0.2338 - accuracy: 0.9825 - dice_coef: 0.7529 - jaccard_score: 0.5806 - precision: 0.8803 - recall: 0.5753 - val_loss: 0.3711 - val_accuracy: 0.9707 - val_dice_coef: 0.6767 - val_jaccard_score: 0.4992 - val_precision: 0.6599 - val_recall: 0.7323 - lr: 0.0010
# Epoch 8/150
# 48/48 [==============================] - ETA: 0s - loss: 0.2417 - accuracy: 0.9825 - dice_coef: 0.7402 - jaccard_score: 0.5671 - precision: 0.8727 - recall: 0.5593
# Epoch 8: val_loss did not improve from 0.37108
# 48/48 [==============================] - 16s 324ms/step - loss: 0.2417 - accuracy: 0.9825 - dice_coef: 0.7402 - jaccard_score: 0.5671 - precision: 0.8727 - recall: 0.5593 - val_loss: 0.4486 - val_accuracy: 0.9625 - val_dice_coef: 0.6164 - val_jaccard_score: 0.4398 - val_precision: 0.5548 - val_recall: 0.7910 - lr: 0.0010
# Epoch 9/150
# 48/48 [==============================] - ETA: 0s - loss: 0.2216 - accuracy: 0.9822 - dice_coef: 0.7612 - jaccard_score: 0.5926 - precision: 0.8882 - recall: 0.5793
# Epoch 9: val_loss improved from 0.37108 to 0.35393, saving model to Segmentation GAN WEIGHTS/2D\UNET_ATT_MULTIPLY.h5
# 48/48 [==============================] - 16s 330ms/step - loss: 0.2216 - accuracy: 0.9822 - dice_coef: 0.7612 - jaccard_score: 0.5926 - precision: 0.8882 - recall: 0.5793 - val_loss: 0.3539 - val_accuracy: 0.9714 - val_dice_coef: 0.6837 - val_jaccard_score: 0.5096 - val_precision: 0.6804 - val_recall: 0.6840 - lr: 0.0010
# Epoch 10/150
# 48/48 [==============================] - ETA: 0s - loss: 0.2164 - accuracy: 0.9837 - dice_coef: 0.7677 - jaccard_score: 0.6050 - precision: 0.8875 - recall: 0.5942
# Epoch 10: val_loss improved from 0.35393 to 0.33287, saving model to Segmentation GAN WEIGHTS/2D\UNET_ATT_MULTIPLY.h5
# 48/48 [==============================] - 16s 328ms/step - loss: 0.2164 - accuracy: 0.9837 - dice_coef: 0.7677 - jaccard_score: 0.6050 - precision: 0.8875 - recall: 0.5942 - val_loss: 0.3329 - val_accuracy: 0.9735 - val_dice_coef: 0.6927 - val_jaccard_score: 0.5249 - val_precision: 0.7163 - val_recall: 0.6816 - lr: 0.0010
# Epoch 11/150
# 48/48 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.9829 - dice_coef: 0.7699 - jaccard_score: 0.6074 - precision: 0.8949 - recall: 0.5891
# Epoch 11: val_loss did not improve from 0.33287
# 48/48 [==============================] - 16s 323ms/step - loss: 0.2117 - accuracy: 0.9829 - dice_coef: 0.7699 - jaccard_score: 0.6074 - precision: 0.8949 - recall: 0.5891 - val_loss: 0.3347 - val_accuracy: 0.9734 - val_dice_coef: 0.6885 - val_jaccard_score: 0.5176 - val_precision: 0.7195 - val_recall: 0.6464 - lr: 0.0010
# Epoch 12/150
# 48/48 [==============================] - ETA: 0s - loss: 0.2164 - accuracy: 0.9835 - dice_coef: 0.7634 - jaccard_score: 0.5996 - precision: 0.8914 - recall: 0.5826
# Epoch 12: val_loss improved from 0.33287 to 0.30214, saving model to Segmentation GAN WEIGHTS/2D\UNET_ATT_MULTIPLY.h5
# 48/48 [==============================] - 16s 330ms/step - loss: 0.2164 - accuracy: 0.9835 - dice_coef: 0.7634 - jaccard_score: 0.5996 - precision: 0.8914 - recall: 0.5826 - val_loss: 0.3021 - val_accuracy: 0.9753 - val_dice_coef: 0.7036 - val_jaccard_score: 0.5364 - val_precision: 0.7765 - val_recall: 0.6104 - lr: 0.0010
# Epoch 13/150
# 48/48 [==============================] - ETA: 0s - loss: 0.2044 - accuracy: 0.9841 - dice_coef: 0.7789 - jaccard_score: 0.6198 - precision: 0.8959 - recall: 0.6005
# Epoch 13: val_loss did not improve from 0.30214
# 48/48 [==============================] - 16s 327ms/step - loss: 0.2044 - accuracy: 0.9841 - dice_coef: 0.7789 - jaccard_score: 0.6198 - precision: 0.8959 - recall: 0.6005 - val_loss: 0.3301 - val_accuracy: 0.9740 - val_dice_coef: 0.6824 - val_jaccard_score: 0.5137 - val_precision: 0.7436 - val_recall: 0.6234 - lr: 0.0010
# Epoch 14/150
# 48/48 [==============================] - ETA: 0s - loss: 0.2032 - accuracy: 0.9837 - dice_coef: 0.7741 - jaccard_score: 0.6135 - precision: 0.9027 - recall: 0.5889
# Epoch 14: val_loss improved from 0.30214 to 0.28717, saving model to Segmentation GAN WEIGHTS/2D\UNET_ATT_MULTIPLY.h5
# 48/48 [==============================] - 16s 338ms/step - loss: 0.2032 - accuracy: 0.9837 - dice_coef: 0.7741 - jaccard_score: 0.6135 - precision: 0.9027 - recall: 0.5889 - val_loss: 0.2872 - val_accuracy: 0.9760 - val_dice_coef: 0.6982 - val_jaccard_score: 0.5324 - val_precision: 0.8340 - val_recall: 0.5518 - lr: 0.0010
# Epoch 15/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1826 - accuracy: 0.9843 - dice_coef: 0.8000 - jaccard_score: 0.6482 - precision: 0.9119 - recall: 0.6147
# Epoch 15: val_loss improved from 0.28717 to 0.28133, saving model to Segmentation GAN WEIGHTS/2D\UNET_ATT_MULTIPLY.h5
# 48/48 [==============================] - 16s 338ms/step - loss: 0.1826 - accuracy: 0.9843 - dice_coef: 0.8000 - jaccard_score: 0.6482 - precision: 0.9119 - recall: 0.6147 - val_loss: 0.2813 - val_accuracy: 0.9761 - val_dice_coef: 0.6982 - val_jaccard_score: 0.5333 - val_precision: 0.8488 - val_recall: 0.5343 - lr: 0.0010
# Epoch 16/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1851 - accuracy: 0.9838 - dice_coef: 0.7971 - jaccard_score: 0.6455 - precision: 0.9109 - recall: 0.6185
# Epoch 16: val_loss did not improve from 0.28133
# 48/48 [==============================] - 16s 328ms/step - loss: 0.1851 - accuracy: 0.9838 - dice_coef: 0.7971 - jaccard_score: 0.6455 - precision: 0.9109 - recall: 0.6185 - val_loss: 0.3003 - val_accuracy: 0.9755 - val_dice_coef: 0.6937 - val_jaccard_score: 0.5263 - val_precision: 0.7964 - val_recall: 0.5783 - lr: 0.0010
# Epoch 17/150
# 48/48 [==============================] - ETA: 0s - loss: 0.2029 - accuracy: 0.9835 - dice_coef: 0.7744 - jaccard_score: 0.6156 - precision: 0.8997 - recall: 0.5940
# Epoch 17: val_loss did not improve from 0.28133
# 48/48 [==============================] - 16s 326ms/step - loss: 0.2029 - accuracy: 0.9835 - dice_coef: 0.7744 - jaccard_score: 0.6156 - precision: 0.8997 - recall: 0.5940 - val_loss: 0.3351 - val_accuracy: 0.9733 - val_dice_coef: 0.6762 - val_jaccard_score: 0.5060 - val_precision: 0.7255 - val_recall: 0.6117 - lr: 0.0010
# Epoch 18/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1931 - accuracy: 0.9845 - dice_coef: 0.7842 - jaccard_score: 0.6282 - precision: 0.9045 - recall: 0.6032
# Epoch 18: val_loss did not improve from 0.28133
# 48/48 [==============================] - 15s 321ms/step - loss: 0.1931 - accuracy: 0.9845 - dice_coef: 0.7842 - jaccard_score: 0.6282 - precision: 0.9045 - recall: 0.6032 - val_loss: 0.3468 - val_accuracy: 0.9727 - val_dice_coef: 0.6877 - val_jaccard_score: 0.5198 - val_precision: 0.6975 - val_recall: 0.6938 - lr: 0.0010
# Epoch 19/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1774 - accuracy: 0.9844 - dice_coef: 0.8072 - jaccard_score: 0.6609 - precision: 0.9111 - recall: 0.6319
# Epoch 19: val_loss did not improve from 0.28133
# 48/48 [==============================] - 16s 323ms/step - loss: 0.1774 - accuracy: 0.9844 - dice_coef: 0.8072 - jaccard_score: 0.6609 - precision: 0.9111 - recall: 0.6319 - val_loss: 0.2987 - val_accuracy: 0.9757 - val_dice_coef: 0.6777 - val_jaccard_score: 0.5100 - val_precision: 0.8288 - val_recall: 0.5317 - lr: 0.0010
# Epoch 20/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1710 - accuracy: 0.9843 - dice_coef: 0.8090 - jaccard_score: 0.6628 - precision: 0.9236 - recall: 0.6232
# Epoch 20: val_loss did not improve from 0.28133
# 48/48 [==============================] - 16s 322ms/step - loss: 0.1710 - accuracy: 0.9843 - dice_coef: 0.8090 - jaccard_score: 0.6628 - precision: 0.9236 - recall: 0.6232 - val_loss: 0.2912 - val_accuracy: 0.9758 - val_dice_coef: 0.6792 - val_jaccard_score: 0.5123 - val_precision: 0.8453 - val_recall: 0.5148 - lr: 0.0010
# Epoch 21/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1767 - accuracy: 0.9845 - dice_coef: 0.8062 - jaccard_score: 0.6599 - precision: 0.9100 - recall: 0.6302
# Epoch 21: val_loss did not improve from 0.28133
# 48/48 [==============================] - 16s 325ms/step - loss: 0.1767 - accuracy: 0.9845 - dice_coef: 0.8062 - jaccard_score: 0.6599 - precision: 0.9100 - recall: 0.6302 - val_loss: 0.3244 - val_accuracy: 0.9739 - val_dice_coef: 0.6836 - val_jaccard_score: 0.5157 - val_precision: 0.7494 - val_recall: 0.5945 - lr: 0.0010
# Epoch 22/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1734 - accuracy: 0.9837 - dice_coef: 0.8036 - jaccard_score: 0.6555 - precision: 0.9262 - recall: 0.6149
# Epoch 22: val_loss did not improve from 0.28133
# 48/48 [==============================] - 16s 338ms/step - loss: 0.1734 - accuracy: 0.9837 - dice_coef: 0.8036 - jaccard_score: 0.6555 - precision: 0.9262 - recall: 0.6149 - val_loss: 0.2835 - val_accuracy: 0.9760 - val_dice_coef: 0.6772 - val_jaccard_score: 0.5123 - val_precision: 0.8748 - val_recall: 0.4940 - lr: 0.0010
# Epoch 23/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1734 - accuracy: 0.9853 - dice_coef: 0.8062 - jaccard_score: 0.6598 - precision: 0.9197 - recall: 0.6238
# Epoch 23: val_loss did not improve from 0.28133
# 48/48 [==============================] - 16s 330ms/step - loss: 0.1734 - accuracy: 0.9853 - dice_coef: 0.8062 - jaccard_score: 0.6598 - precision: 0.9197 - recall: 0.6238 - val_loss: 0.2949 - val_accuracy: 0.9755 - val_dice_coef: 0.6867 - val_jaccard_score: 0.5209 - val_precision: 0.8223 - val_recall: 0.5381 - lr: 0.0010
# Epoch 24/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1873 - accuracy: 0.9845 - dice_coef: 0.7887 - jaccard_score: 0.6360 - precision: 0.9161 - recall: 0.6028
# Epoch 24: val_loss did not improve from 0.28133
# 48/48 [==============================] - 16s 331ms/step - loss: 0.1873 - accuracy: 0.9845 - dice_coef: 0.7887 - jaccard_score: 0.6360 - precision: 0.9161 - recall: 0.6028 - val_loss: 0.3000 - val_accuracy: 0.9751 - val_dice_coef: 0.6970 - val_jaccard_score: 0.5319 - val_precision: 0.7915 - val_recall: 0.5803 - lr: 0.0010
# Epoch 25/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1671 - accuracy: 0.9845 - dice_coef: 0.8127 - jaccard_score: 0.6682 - precision: 0.9287 - recall: 0.6272
# Epoch 25: val_loss did not improve from 0.28133
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 48/48 [==============================] - 16s 328ms/step - loss: 0.1671 - accuracy: 0.9845 - dice_coef: 0.8127 - jaccard_score: 0.6682 - precision: 0.9287 - recall: 0.6272 - val_loss: 0.3285 - val_accuracy: 0.9732 - val_dice_coef: 0.6906 - val_jaccard_score: 0.5242 - val_precision: 0.7143 - val_recall: 0.6440 - lr: 0.0010
# Epoch 26/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1504 - accuracy: 0.9854 - dice_coef: 0.8327 - jaccard_score: 0.6969 - precision: 0.9326 - recall: 0.6487
# Epoch 26: val_loss did not improve from 0.28133
# 48/48 [==============================] - 16s 326ms/step - loss: 0.1504 - accuracy: 0.9854 - dice_coef: 0.8327 - jaccard_score: 0.6969 - precision: 0.9326 - recall: 0.6487 - val_loss: 0.2882 - val_accuracy: 0.9760 - val_dice_coef: 0.6767 - val_jaccard_score: 0.5100 - val_precision: 0.8621 - val_recall: 0.5008 - lr: 5.0000e-04
# Epoch 27/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1500 - accuracy: 0.9854 - dice_coef: 0.8309 - jaccard_score: 0.6948 - precision: 0.9380 - recall: 0.6486
# Epoch 27: val_loss did not improve from 0.28133
# 48/48 [==============================] - 16s 330ms/step - loss: 0.1500 - accuracy: 0.9854 - dice_coef: 0.8309 - jaccard_score: 0.6948 - precision: 0.9380 - recall: 0.6486 - val_loss: 0.2817 - val_accuracy: 0.9762 - val_dice_coef: 0.7010 - val_jaccard_score: 0.5352 - val_precision: 0.8283 - val_recall: 0.5540 - lr: 5.0000e-04
# Epoch 28/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1583 - accuracy: 0.9855 - dice_coef: 0.8202 - jaccard_score: 0.6795 - precision: 0.9339 - recall: 0.6289
# Epoch 28: val_loss did not improve from 0.28133
# 48/48 [==============================] - 16s 334ms/step - loss: 0.1583 - accuracy: 0.9855 - dice_coef: 0.8202 - jaccard_score: 0.6795 - precision: 0.9339 - recall: 0.6289 - val_loss: 0.2920 - val_accuracy: 0.9755 - val_dice_coef: 0.6937 - val_jaccard_score: 0.5288 - val_precision: 0.8133 - val_recall: 0.5541 - lr: 5.0000e-04
# Epoch 29/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1663 - accuracy: 0.9855 - dice_coef: 0.8104 - jaccard_score: 0.6668 - precision: 0.9307 - recall: 0.6239
# Epoch 29: val_loss improved from 0.28133 to 0.28071, saving model to Segmentation GAN WEIGHTS/2D\UNET_ATT_MULTIPLY.h5
# 48/48 [==============================] - 16s 334ms/step - loss: 0.1663 - accuracy: 0.9855 - dice_coef: 0.8104 - jaccard_score: 0.6668 - precision: 0.9307 - recall: 0.6239 - val_loss: 0.2807 - val_accuracy: 0.9760 - val_dice_coef: 0.6975 - val_jaccard_score: 0.5342 - val_precision: 0.8359 - val_recall: 0.5426 - lr: 5.0000e-04
# Epoch 30/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1493 - accuracy: 0.9859 - dice_coef: 0.8335 - jaccard_score: 0.6992 - precision: 0.9360 - recall: 0.6481
# Epoch 30: val_loss improved from 0.28071 to 0.27280, saving model to Segmentation GAN WEIGHTS/2D\UNET_ATT_MULTIPLY.h5
# 48/48 [==============================] - 16s 331ms/step - loss: 0.1493 - accuracy: 0.9859 - dice_coef: 0.8335 - jaccard_score: 0.6992 - precision: 0.9360 - recall: 0.6481 - val_loss: 0.2728 - val_accuracy: 0.9765 - val_dice_coef: 0.6983 - val_jaccard_score: 0.5357 - val_precision: 0.8582 - val_recall: 0.5329 - lr: 5.0000e-04
# Epoch 31/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1429 - accuracy: 0.9862 - dice_coef: 0.8374 - jaccard_score: 0.7058 - precision: 0.9441 - recall: 0.6524
# Epoch 31: val_loss improved from 0.27280 to 0.27207, saving model to Segmentation GAN WEIGHTS/2D\UNET_ATT_MULTIPLY.h5
# 48/48 [==============================] - 16s 332ms/step - loss: 0.1429 - accuracy: 0.9862 - dice_coef: 0.8374 - jaccard_score: 0.7058 - precision: 0.9441 - recall: 0.6524 - val_loss: 0.2721 - val_accuracy: 0.9766 - val_dice_coef: 0.7017 - val_jaccard_score: 0.5385 - val_precision: 0.8538 - val_recall: 0.5410 - lr: 5.0000e-04
# Epoch 32/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1349 - accuracy: 0.9861 - dice_coef: 0.8481 - jaccard_score: 0.7207 - precision: 0.9451 - recall: 0.6664
# Epoch 32: val_loss did not improve from 0.27207
# 48/48 [==============================] - 16s 323ms/step - loss: 0.1349 - accuracy: 0.9861 - dice_coef: 0.8481 - jaccard_score: 0.7207 - precision: 0.9451 - recall: 0.6664 - val_loss: 0.2875 - val_accuracy: 0.9758 - val_dice_coef: 0.6746 - val_jaccard_score: 0.5092 - val_precision: 0.8649 - val_recall: 0.4947 - lr: 5.0000e-04
# Epoch 33/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1571 - accuracy: 0.9854 - dice_coef: 0.8225 - jaccard_score: 0.6837 - precision: 0.9326 - recall: 0.6368
# Epoch 33: val_loss did not improve from 0.27207
# 48/48 [==============================] - 16s 341ms/step - loss: 0.1571 - accuracy: 0.9854 - dice_coef: 0.8225 - jaccard_score: 0.6837 - precision: 0.9326 - recall: 0.6368 - val_loss: 0.2890 - val_accuracy: 0.9759 - val_dice_coef: 0.6843 - val_jaccard_score: 0.5206 - val_precision: 0.8417 - val_recall: 0.5265 - lr: 5.0000e-04
# Epoch 34/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9857 - dice_coef: 0.8396 - jaccard_score: 0.7079 - precision: 0.9386 - recall: 0.6586
# Epoch 34: val_loss did not improve from 0.27207
# 48/48 [==============================] - 15s 315ms/step - loss: 0.1426 - accuracy: 0.9857 - dice_coef: 0.8396 - jaccard_score: 0.7079 - precision: 0.9386 - recall: 0.6586 - val_loss: 0.2846 - val_accuracy: 0.9760 - val_dice_coef: 0.6855 - val_jaccard_score: 0.5216 - val_precision: 0.8497 - val_recall: 0.5183 - lr: 5.0000e-04
# Epoch 35/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 0.9857 - dice_coef: 0.8429 - jaccard_score: 0.7139 - precision: 0.9494 - recall: 0.6551
# Epoch 35: val_loss did not improve from 0.27207
# 48/48 [==============================] - 15s 305ms/step - loss: 0.1344 - accuracy: 0.9857 - dice_coef: 0.8429 - jaccard_score: 0.7139 - precision: 0.9494 - recall: 0.6551 - val_loss: 0.2881 - val_accuracy: 0.9757 - val_dice_coef: 0.6933 - val_jaccard_score: 0.5282 - val_precision: 0.8194 - val_recall: 0.5494 - lr: 5.0000e-04
# Epoch 36/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1324 - accuracy: 0.9864 - dice_coef: 0.8517 - jaccard_score: 0.7262 - precision: 0.9458 - recall: 0.6721
# Epoch 36: val_loss did not improve from 0.27207
# 48/48 [==============================] - 15s 309ms/step - loss: 0.1324 - accuracy: 0.9864 - dice_coef: 0.8517 - jaccard_score: 0.7262 - precision: 0.9458 - recall: 0.6721 - val_loss: 0.2813 - val_accuracy: 0.9763 - val_dice_coef: 0.7009 - val_jaccard_score: 0.5367 - val_precision: 0.8283 - val_recall: 0.5610 - lr: 5.0000e-04
# Epoch 37/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1334 - accuracy: 0.9862 - dice_coef: 0.8481 - jaccard_score: 0.7209 - precision: 0.9483 - recall: 0.6632
# Epoch 37: val_loss did not improve from 0.27207
# 48/48 [==============================] - 16s 328ms/step - loss: 0.1334 - accuracy: 0.9862 - dice_coef: 0.8481 - jaccard_score: 0.7209 - precision: 0.9483 - recall: 0.6632 - val_loss: 0.2926 - val_accuracy: 0.9755 - val_dice_coef: 0.6851 - val_jaccard_score: 0.5199 - val_precision: 0.8231 - val_recall: 0.5348 - lr: 5.0000e-04
# Epoch 38/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1305 - accuracy: 0.9861 - dice_coef: 0.8532 - jaccard_score: 0.7289 - precision: 0.9484 - recall: 0.6706
# Epoch 38: val_loss did not improve from 0.27207
# 48/48 [==============================] - 16s 323ms/step - loss: 0.1305 - accuracy: 0.9861 - dice_coef: 0.8532 - jaccard_score: 0.7289 - precision: 0.9484 - recall: 0.6706 - val_loss: 0.2837 - val_accuracy: 0.9759 - val_dice_coef: 0.7081 - val_jaccard_score: 0.5454 - val_precision: 0.8027 - val_recall: 0.5857 - lr: 5.0000e-04
# Epoch 39/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1360 - accuracy: 0.9866 - dice_coef: 0.8447 - jaccard_score: 0.7168 - precision: 0.9461 - recall: 0.6593
# Epoch 39: val_loss did not improve from 0.27207
# 48/48 [==============================] - 16s 328ms/step - loss: 0.1360 - accuracy: 0.9866 - dice_coef: 0.8447 - jaccard_score: 0.7168 - precision: 0.9461 - recall: 0.6593 - val_loss: 0.2834 - val_accuracy: 0.9759 - val_dice_coef: 0.6864 - val_jaccard_score: 0.5222 - val_precision: 0.8509 - val_recall: 0.5163 - lr: 5.0000e-04
# Epoch 40/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1418 - accuracy: 0.9858 - dice_coef: 0.8401 - jaccard_score: 0.7097 - precision: 0.9417 - recall: 0.6572
# Epoch 40: val_loss did not improve from 0.27207
# 48/48 [==============================] - 16s 332ms/step - loss: 0.1418 - accuracy: 0.9858 - dice_coef: 0.8401 - jaccard_score: 0.7097 - precision: 0.9417 - recall: 0.6572 - val_loss: 0.2898 - val_accuracy: 0.9758 - val_dice_coef: 0.6729 - val_jaccard_score: 0.5061 - val_precision: 0.8628 - val_recall: 0.4951 - lr: 5.0000e-04
# Epoch 41/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1418 - accuracy: 0.9855 - dice_coef: 0.8385 - jaccard_score: 0.7076 - precision: 0.9433 - recall: 0.6521
# Epoch 41: val_loss did not improve from 0.27207
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 48/48 [==============================] - 15s 312ms/step - loss: 0.1418 - accuracy: 0.9855 - dice_coef: 0.8385 - jaccard_score: 0.7076 - precision: 0.9433 - recall: 0.6521 - val_loss: 0.2951 - val_accuracy: 0.9758 - val_dice_coef: 0.6984 - val_jaccard_score: 0.5353 - val_precision: 0.7995 - val_recall: 0.5870 - lr: 5.0000e-04
# Epoch 42/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1225 - accuracy: 0.9862 - dice_coef: 0.8618 - jaccard_score: 0.7411 - precision: 0.9521 - recall: 0.6799
# Epoch 42: val_loss did not improve from 0.27207
# 48/48 [==============================] - 16s 326ms/step - loss: 0.1225 - accuracy: 0.9862 - dice_coef: 0.8618 - jaccard_score: 0.7411 - precision: 0.9521 - recall: 0.6799 - val_loss: 0.2752 - val_accuracy: 0.9765 - val_dice_coef: 0.7088 - val_jaccard_score: 0.5463 - val_precision: 0.8268 - val_recall: 0.5716 - lr: 2.5000e-04
# Epoch 43/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1302 - accuracy: 0.9863 - dice_coef: 0.8510 - jaccard_score: 0.7255 - precision: 0.9510 - recall: 0.6619
# Epoch 43: val_loss did not improve from 0.27207
# 48/48 [==============================] - 16s 328ms/step - loss: 0.1302 - accuracy: 0.9863 - dice_coef: 0.8510 - jaccard_score: 0.7255 - precision: 0.9510 - recall: 0.6619 - val_loss: 0.2765 - val_accuracy: 0.9763 - val_dice_coef: 0.6941 - val_jaccard_score: 0.5313 - val_precision: 0.8556 - val_recall: 0.5284 - lr: 2.5000e-04
# Epoch 44/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1214 - accuracy: 0.9868 - dice_coef: 0.8610 - jaccard_score: 0.7414 - precision: 0.9562 - recall: 0.6751
# Epoch 44: val_loss improved from 0.27207 to 0.27078, saving model to Segmentation GAN WEIGHTS/2D\UNET_ATT_MULTIPLY.h5
# 48/48 [==============================] - 16s 336ms/step - loss: 0.1214 - accuracy: 0.9868 - dice_coef: 0.8610 - jaccard_score: 0.7414 - precision: 0.9562 - recall: 0.6751 - val_loss: 0.2708 - val_accuracy: 0.9766 - val_dice_coef: 0.7004 - val_jaccard_score: 0.5381 - val_precision: 0.8584 - val_recall: 0.5364 - lr: 2.5000e-04
# Epoch 45/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 0.9866 - dice_coef: 0.8615 - jaccard_score: 0.7423 - precision: 0.9537 - recall: 0.6792
# Epoch 45: val_loss did not improve from 0.27078
# 48/48 [==============================] - 16s 330ms/step - loss: 0.1216 - accuracy: 0.9866 - dice_coef: 0.8615 - jaccard_score: 0.7423 - precision: 0.9537 - recall: 0.6792 - val_loss: 0.2831 - val_accuracy: 0.9761 - val_dice_coef: 0.6976 - val_jaccard_score: 0.5340 - val_precision: 0.8272 - val_recall: 0.5530 - lr: 2.5000e-04
# Epoch 46/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1233 - accuracy: 0.9869 - dice_coef: 0.8597 - jaccard_score: 0.7391 - precision: 0.9541 - recall: 0.6759
# Epoch 46: val_loss did not improve from 0.27078
# 48/48 [==============================] - 16s 327ms/step - loss: 0.1233 - accuracy: 0.9869 - dice_coef: 0.8597 - jaccard_score: 0.7391 - precision: 0.9541 - recall: 0.6759 - val_loss: 0.2788 - val_accuracy: 0.9763 - val_dice_coef: 0.6879 - val_jaccard_score: 0.5235 - val_precision: 0.8578 - val_recall: 0.5186 - lr: 2.5000e-04
# Epoch 47/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1225 - accuracy: 0.9869 - dice_coef: 0.8590 - jaccard_score: 0.7385 - precision: 0.9535 - recall: 0.6704
# Epoch 47: val_loss did not improve from 0.27078
# 48/48 [==============================] - 16s 324ms/step - loss: 0.1225 - accuracy: 0.9869 - dice_coef: 0.8590 - jaccard_score: 0.7385 - precision: 0.9535 - recall: 0.6704 - val_loss: 0.2784 - val_accuracy: 0.9763 - val_dice_coef: 0.6852 - val_jaccard_score: 0.5217 - val_precision: 0.8659 - val_recall: 0.5102 - lr: 2.5000e-04
# Epoch 48/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1135 - accuracy: 0.9872 - dice_coef: 0.8702 - jaccard_score: 0.7557 - precision: 0.9574 - recall: 0.6871
# Epoch 48: val_loss did not improve from 0.27078
# 48/48 [==============================] - 16s 327ms/step - loss: 0.1135 - accuracy: 0.9872 - dice_coef: 0.8702 - jaccard_score: 0.7557 - precision: 0.9574 - recall: 0.6871 - val_loss: 0.2766 - val_accuracy: 0.9762 - val_dice_coef: 0.6912 - val_jaccard_score: 0.5283 - val_precision: 0.8573 - val_recall: 0.5204 - lr: 2.5000e-04
# Epoch 49/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1182 - accuracy: 0.9869 - dice_coef: 0.8662 - jaccard_score: 0.7493 - precision: 0.9545 - recall: 0.6842
# Epoch 49: val_loss did not improve from 0.27078
# 48/48 [==============================] - 16s 325ms/step - loss: 0.1182 - accuracy: 0.9869 - dice_coef: 0.8662 - jaccard_score: 0.7493 - precision: 0.9545 - recall: 0.6842 - val_loss: 0.2876 - val_accuracy: 0.9758 - val_dice_coef: 0.6949 - val_jaccard_score: 0.5321 - val_precision: 0.8178 - val_recall: 0.5557 - lr: 2.5000e-04
# Epoch 50/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1193 - accuracy: 0.9869 - dice_coef: 0.8635 - jaccard_score: 0.7456 - precision: 0.9573 - recall: 0.6787
# Epoch 50: val_loss did not improve from 0.27078
# 48/48 [==============================] - 16s 326ms/step - loss: 0.1193 - accuracy: 0.9869 - dice_coef: 0.8635 - jaccard_score: 0.7456 - precision: 0.9573 - recall: 0.6787 - val_loss: 0.2758 - val_accuracy: 0.9764 - val_dice_coef: 0.7041 - val_jaccard_score: 0.5418 - val_precision: 0.8345 - val_recall: 0.5557 - lr: 2.5000e-04
# Epoch 51/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.9862 - dice_coef: 0.8594 - jaccard_score: 0.7389 - precision: 0.9591 - recall: 0.6710
# Epoch 51: val_loss did not improve from 0.27078
# 48/48 [==============================] - 16s 328ms/step - loss: 0.1205 - accuracy: 0.9862 - dice_coef: 0.8594 - jaccard_score: 0.7389 - precision: 0.9591 - recall: 0.6710 - val_loss: 0.2792 - val_accuracy: 0.9762 - val_dice_coef: 0.7083 - val_jaccard_score: 0.5468 - val_precision: 0.8171 - val_recall: 0.5796 - lr: 2.5000e-04
# Epoch 52/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1165 - accuracy: 0.9870 - dice_coef: 0.8665 - jaccard_score: 0.7509 - precision: 0.9567 - recall: 0.6856
# Epoch 52: val_loss did not improve from 0.27078
# 48/48 [==============================] - 16s 328ms/step - loss: 0.1165 - accuracy: 0.9870 - dice_coef: 0.8665 - jaccard_score: 0.7509 - precision: 0.9567 - recall: 0.6856 - val_loss: 0.2778 - val_accuracy: 0.9764 - val_dice_coef: 0.7094 - val_jaccard_score: 0.5480 - val_precision: 0.8172 - val_recall: 0.5833 - lr: 2.5000e-04
# Epoch 53/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1193 - accuracy: 0.9867 - dice_coef: 0.8625 - jaccard_score: 0.7441 - precision: 0.9553 - recall: 0.6803
# Epoch 53: val_loss did not improve from 0.27078
# 48/48 [==============================] - 16s 328ms/step - loss: 0.1193 - accuracy: 0.9867 - dice_coef: 0.8625 - jaccard_score: 0.7441 - precision: 0.9553 - recall: 0.6803 - val_loss: 0.2746 - val_accuracy: 0.9763 - val_dice_coef: 0.6933 - val_jaccard_score: 0.5308 - val_precision: 0.8567 - val_recall: 0.5237 - lr: 2.5000e-04
# Epoch 54/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9874 - dice_coef: 0.8704 - jaccard_score: 0.7564 - precision: 0.9585 - recall: 0.6888
# Epoch 54: val_loss did not improve from 0.27078
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 48/48 [==============================] - 15s 308ms/step - loss: 0.1134 - accuracy: 0.9874 - dice_coef: 0.8704 - jaccard_score: 0.7564 - precision: 0.9585 - recall: 0.6888 - val_loss: 0.2795 - val_accuracy: 0.9761 - val_dice_coef: 0.6842 - val_jaccard_score: 0.5225 - val_precision: 0.8668 - val_recall: 0.5058 - lr: 2.5000e-04
# Epoch 55/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1160 - accuracy: 0.9867 - dice_coef: 0.8684 - jaccard_score: 0.7530 - precision: 0.9564 - recall: 0.6865
# Epoch 55: val_loss did not improve from 0.27078
# 48/48 [==============================] - 16s 330ms/step - loss: 0.1160 - accuracy: 0.9867 - dice_coef: 0.8684 - jaccard_score: 0.7530 - precision: 0.9564 - recall: 0.6865 - val_loss: 0.2752 - val_accuracy: 0.9763 - val_dice_coef: 0.6914 - val_jaccard_score: 0.5287 - val_precision: 0.8620 - val_recall: 0.5182 - lr: 1.2500e-04
# Epoch 56/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1149 - accuracy: 0.9870 - dice_coef: 0.8682 - jaccard_score: 0.7529 - precision: 0.9590 - recall: 0.6824
# Epoch 56: val_loss did not improve from 0.27078
# 48/48 [==============================] - 16s 332ms/step - loss: 0.1149 - accuracy: 0.9870 - dice_coef: 0.8682 - jaccard_score: 0.7529 - precision: 0.9590 - recall: 0.6824 - val_loss: 0.2741 - val_accuracy: 0.9765 - val_dice_coef: 0.7055 - val_jaccard_score: 0.5439 - val_precision: 0.8351 - val_recall: 0.5578 - lr: 1.2500e-04
# Epoch 57/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9872 - dice_coef: 0.8709 - jaccard_score: 0.7570 - precision: 0.9586 - recall: 0.6913
# Epoch 57: val_loss did not improve from 0.27078
# 48/48 [==============================] - 16s 323ms/step - loss: 0.1134 - accuracy: 0.9872 - dice_coef: 0.8709 - jaccard_score: 0.7570 - precision: 0.9586 - recall: 0.6913 - val_loss: 0.2730 - val_accuracy: 0.9765 - val_dice_coef: 0.7051 - val_jaccard_score: 0.5437 - val_precision: 0.8397 - val_recall: 0.5563 - lr: 1.2500e-04
# Epoch 58/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1144 - accuracy: 0.9865 - dice_coef: 0.8673 - jaccard_score: 0.7510 - precision: 0.9611 - recall: 0.6798
# Epoch 58: val_loss did not improve from 0.27078
# 48/48 [==============================] - 15s 304ms/step - loss: 0.1144 - accuracy: 0.9865 - dice_coef: 0.8673 - jaccard_score: 0.7510 - precision: 0.9611 - recall: 0.6798 - val_loss: 0.2736 - val_accuracy: 0.9765 - val_dice_coef: 0.7045 - val_jaccard_score: 0.5434 - val_precision: 0.8394 - val_recall: 0.5572 - lr: 1.2500e-04
# Epoch 59/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1071 - accuracy: 0.9868 - dice_coef: 0.8779 - jaccard_score: 0.7677 - precision: 0.9614 - recall: 0.6939
# Epoch 59: val_loss did not improve from 0.27078
# 48/48 [==============================] - 15s 315ms/step - loss: 0.1071 - accuracy: 0.9868 - dice_coef: 0.8779 - jaccard_score: 0.7677 - precision: 0.9614 - recall: 0.6939 - val_loss: 0.2741 - val_accuracy: 0.9766 - val_dice_coef: 0.7068 - val_jaccard_score: 0.5457 - val_precision: 0.8328 - val_recall: 0.5665 - lr: 1.2500e-04
# Epoch 60/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1094 - accuracy: 0.9867 - dice_coef: 0.8723 - jaccard_score: 0.7591 - precision: 0.9641 - recall: 0.6842
# Epoch 60: val_loss did not improve from 0.27078
# 48/48 [==============================] - 15s 315ms/step - loss: 0.1094 - accuracy: 0.9867 - dice_coef: 0.8723 - jaccard_score: 0.7591 - precision: 0.9641 - recall: 0.6842 - val_loss: 0.2751 - val_accuracy: 0.9766 - val_dice_coef: 0.7049 - val_jaccard_score: 0.5438 - val_precision: 0.8358 - val_recall: 0.5647 - lr: 1.2500e-04
# Epoch 61/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1103 - accuracy: 0.9871 - dice_coef: 0.8746 - jaccard_score: 0.7628 - precision: 0.9585 - recall: 0.6971
# Epoch 61: val_loss did not improve from 0.27078
# 48/48 [==============================] - 15s 309ms/step - loss: 0.1103 - accuracy: 0.9871 - dice_coef: 0.8746 - jaccard_score: 0.7628 - precision: 0.9585 - recall: 0.6971 - val_loss: 0.2817 - val_accuracy: 0.9761 - val_dice_coef: 0.6999 - val_jaccard_score: 0.5379 - val_precision: 0.8250 - val_recall: 0.5598 - lr: 1.2500e-04
# Epoch 62/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1060 - accuracy: 0.9876 - dice_coef: 0.8780 - jaccard_score: 0.7674 - precision: 0.9641 - recall: 0.6918
# Epoch 62: val_loss did not improve from 0.27078
# 48/48 [==============================] - 15s 314ms/step - loss: 0.1060 - accuracy: 0.9876 - dice_coef: 0.8780 - jaccard_score: 0.7674 - precision: 0.9641 - recall: 0.6918 - val_loss: 0.2762 - val_accuracy: 0.9764 - val_dice_coef: 0.7096 - val_jaccard_score: 0.5487 - val_precision: 0.8208 - val_recall: 0.5792 - lr: 1.2500e-04
# Epoch 63/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1117 - accuracy: 0.9874 - dice_coef: 0.8728 - jaccard_score: 0.7594 - precision: 0.9596 - recall: 0.6912
# Epoch 63: val_loss did not improve from 0.27078
# 48/48 [==============================] - 16s 324ms/step - loss: 0.1117 - accuracy: 0.9874 - dice_coef: 0.8728 - jaccard_score: 0.7594 - precision: 0.9596 - recall: 0.6912 - val_loss: 0.2771 - val_accuracy: 0.9763 - val_dice_coef: 0.6950 - val_jaccard_score: 0.5321 - val_precision: 0.8460 - val_recall: 0.5369 - lr: 1.2500e-04
# Epoch 64/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1078 - accuracy: 0.9871 - dice_coef: 0.8746 - jaccard_score: 0.7634 - precision: 0.9643 - recall: 0.6881
# Epoch 64: val_loss did not improve from 0.27078
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 48/48 [==============================] - 16s 329ms/step - loss: 0.1078 - accuracy: 0.9871 - dice_coef: 0.8746 - jaccard_score: 0.7634 - precision: 0.9643 - recall: 0.6881 - val_loss: 0.2750 - val_accuracy: 0.9764 - val_dice_coef: 0.7049 - val_jaccard_score: 0.5436 - val_precision: 0.8313 - val_recall: 0.5611 - lr: 1.2500e-04
# Epoch 65/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1030 - accuracy: 0.9877 - dice_coef: 0.8840 - jaccard_score: 0.7775 - precision: 0.9617 - recall: 0.7045
# Epoch 65: val_loss did not improve from 0.27078
# 48/48 [==============================] - 16s 325ms/step - loss: 0.1030 - accuracy: 0.9877 - dice_coef: 0.8840 - jaccard_score: 0.7775 - precision: 0.9617 - recall: 0.7045 - val_loss: 0.2787 - val_accuracy: 0.9763 - val_dice_coef: 0.7044 - val_jaccard_score: 0.5427 - val_precision: 0.8233 - val_recall: 0.5681 - lr: 6.2500e-05
# Epoch 66/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9871 - dice_coef: 0.8743 - jaccard_score: 0.7619 - precision: 0.9630 - recall: 0.6880
# Epoch 66: val_loss did not improve from 0.27078
# 48/48 [==============================] - 15s 304ms/step - loss: 0.1089 - accuracy: 0.9871 - dice_coef: 0.8743 - jaccard_score: 0.7619 - precision: 0.9630 - recall: 0.6880 - val_loss: 0.2763 - val_accuracy: 0.9764 - val_dice_coef: 0.7003 - val_jaccard_score: 0.5388 - val_precision: 0.8394 - val_recall: 0.5508 - lr: 6.2500e-05
# Epoch 67/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1048 - accuracy: 0.9871 - dice_coef: 0.8798 - jaccard_score: 0.7711 - precision: 0.9637 - recall: 0.6961
# Epoch 67: val_loss did not improve from 0.27078
# 48/48 [==============================] - 14s 300ms/step - loss: 0.1048 - accuracy: 0.9871 - dice_coef: 0.8798 - jaccard_score: 0.7711 - precision: 0.9637 - recall: 0.6961 - val_loss: 0.2793 - val_accuracy: 0.9763 - val_dice_coef: 0.7051 - val_jaccard_score: 0.5438 - val_precision: 0.8212 - val_recall: 0.5709 - lr: 6.2500e-05
# Epoch 68/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1053 - accuracy: 0.9873 - dice_coef: 0.8804 - jaccard_score: 0.7716 - precision: 0.9627 - recall: 0.6970
# Epoch 68: val_loss did not improve from 0.27078
# 48/48 [==============================] - 15s 306ms/step - loss: 0.1053 - accuracy: 0.9873 - dice_coef: 0.8804 - jaccard_score: 0.7716 - precision: 0.9627 - recall: 0.6970 - val_loss: 0.2749 - val_accuracy: 0.9765 - val_dice_coef: 0.7028 - val_jaccard_score: 0.5418 - val_precision: 0.8379 - val_recall: 0.5555 - lr: 6.2500e-05
# Epoch 69/150
# 48/48 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9874 - dice_coef: 0.8803 - jaccard_score: 0.7718 - precision: 0.9644 - recall: 0.6971
# Epoch 69: val_loss did not improve from 0.27078
# 48/48 [==============================] - 15s 305ms/step - loss: 0.1037 - accuracy: 0.9874 - dice_coef: 0.8803 - jaccard_score: 0.7718 - precision: 0.9644 - recall: 0.6971 - val_loss: 0.2813 - val_accuracy: 0.9762 - val_dice_coef: 0.7040 - val_jaccard_score: 0.5425 - val_precision: 0.8179 - val_recall: 0.5710 - lr: 6.2500e-05

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# plt.plot(history.history['Tversky'])
# plt.plot(history.history['val_Tversky'])
# plt.title('model tversky')
# plt.ylabel('Tversky')
# plt.xlabel('epoch')
# plt.legend(['train', 'val'], loc='upper left')
# plt.show()

# %%
model.load_weights("Segmentation GAN WEIGHTS/2D/UNET_ATT_MULTIPLY.h5")
val = model.evaluate(Valid_Images, Valid_Masks, batch_size = 32, verbose = 1)
import os
os._exit(00)
# Out:
# 18/18 [==============================] - 4s 194ms/step - loss: 0.2708 - accuracy: 0.9766 - dice_coef: 0.7004 - jaccard_score: 0.5381 - precision: 0.8584 - recall: 0.5364

# %% [raw]
# from tqdm.notebook import tqdm
# import random
# import time
# h = 256
# w = 256
# c = 1
# J=0
# lr = 1e-3
# min_loss = val[0]
# K.set_value(generator.optimizer.lr, lr)
# K.set_value(discriminator.optimizer.lr, lr)
# K.set_value(adversarial_model.optimizer.lr, lr)
# epochs = 50
# batch_size = 8
# steps_per_epoch = 100
# #validation_steps = 4
# for epoch in range(epochs):
#         print('Epoch ({}/{})-------------------------------------------------'.format(epoch,epochs))
#
#         for i in tqdm(range(steps_per_epoch)):
#         #              batch_x = np.array([next(train_image_generator) for i in range(batch_size)]).reshape(batch_size,target_x, target_y,3)
#         #     batch_y = np.array([next(train_mask_generator) for i in range(batch_size)]).reshape(batch_size,target_x, target_y,1)
#         #     """
#             x_train,y_train = next(train_generator)
# #             x_train = get_patches(x_train,h,w,ph,pw,c).reshape(-1,ph,pw,c)
# #             y_train = get_patches(y_train,h,w,ph,pw,c).reshape(-1,ph,pw,c)
#
# #             x_train,y_train = remove_black_images(x_train,y_train, 0)
#             gc.collect()
#
#
#             ones = np.ones((y_train.shape[0], 1)) - np.random.uniform(0.001, 0.1)
#             zeros = np.zeros((y_train.shape[0], 1)) + np.random.uniform(0.001, 0.1)
#             dis_y_data = [ones,zeros]
#             dis_y_data = np.array(dis_y_data).reshape(-1,1)
#             discriminator.trainable = True
#             Encoder.trainable = False
#             batch_fake_images = generator.predict_on_batch(x_train)
#             batch_fake_images = batch_fake_images.reshape(-1,h,w,c)
#             dis_x_data1 = np.concatenate((x_train,x_train), axis = 0)
#             dis_x_data2 = np.concatenate((y_train,batch_fake_images), axis = 0)
#
#             discriminator.train_on_batch([dis_x_data1,dis_x_data2], dis_y_data)
#
#             gc.collect()
#             del batch_fake_images
#             del dis_x_data1
#             del dis_x_data2
#             del dis_y_data
#             discriminator.trainable = False
#             Encoder.trainable = True
#
#             adversarial_model.train_on_batch(x_train, [y_train,ones])
#         val = generator.evaluate(Valid_Images, Valid_Masks, batch_size = 32, verbose = 1)
#
#         l = val[0]
#         if (l <= min_loss):
#             print("val_loss progressed to: ", val)
#             min_loss = l
#             generator.save_weights("Segmentation GAN WEIGHTS/2D/gen_UNET_NRC_HEAVY.h5")
#             discriminator.save_weights("Segmentation GAN WEIGHTS/2D/dis_UNET_NRC_HEAVY.h5")
#             J=0
#
# #                 generator.load_weights("{}/gen_UNET_NRC2D_COVID_{}_{} P_ {} R.h5".format(directory,Version, best_precision, best_recall))
# #                 discriminator.load_weights("{}/dis_UNET_NRC2D_COVID_{}_{} P_ {} R.h5".format(directory, Version, best_precision, best_recall))
#         else:
#             J+=1
#             if J == 10:
#                 lr = lr*0.5
#                 K.set_value(generator.optimizer.lr, lr)
#                 K.set_value(discriminator.optimizer.lr, lr)
#                 K.set_value(adversarial_model.optimizer.lr, lr)
#                 J=0
#                 print("lr reduced to: ", lr)
# #                 generator.load_weights("{}/gen_UNET_NRC2D_COVID_{}_{} P_ {} R.h5".format(directory,Version, best_precision, best_recall))
# #                 discriminator.load_weights("{}/dis_UNET_NRC2D_COVID_{}_{} P_ {} R.h5".format(directory, Version, best_precision, best_recall))
#         x, y = Valid_Images[300:307], Valid_Masks[300:307]
#         preds = adversarial_model.predict_on_batch(x)[0]
#         visualize(x,y, pred_batch = preds, num_samples=7)

# %% [raw]
# import os
# os._exit(00)

# %% [raw]
# #generator.load_weights("Segmentation GAN WEIGHTS/2D VERSION_1/UNET_NRC2D_SEP_V1.h5")
# #val = generator.evaluate(Valid_Images, Valid_Masks, batch_size = 32, verbose = 1)
# K.set_value(generator.optimizer.lr, 2e-4)

# %% [raw]
# history2 = generator.fit(train_generator, verbose = 1, epochs = 100, validation_data = [Valid_Images, Valid_Masks] , callbacks = [checkpoint,reduce_lr,tf.keras.callbacks.TerminateOnNaN(),TB, early_stopping],
#                          steps_per_epoch = 6235//batch_size,initial_epoch=54)

# %% [raw]
# plt.plot(history2.history['accuracy'])
# plt.plot(history2.history['val_accuracy'])
# plt.title('model accuracy')
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.legend(['train', 'val'], loc='upper left')
# plt.show()
#
# plt.plot(history2.history['loss'])
# plt.plot(history2.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'val'], loc='upper left')
# plt.show()
#
# plt.plot(history2.history['precision'])
# plt.plot(history2.history['val_precision'])
# plt.title('model precision')
# plt.ylabel('precision')
# plt.xlabel('epoch')
# plt.legend(['train', 'val'], loc='upper left')
# plt.show()
#
# plt.plot(history2.history['recall'])
# plt.plot(history2.history['val_recall'])
# plt.title('model recall')
# plt.ylabel('recall')
# plt.xlabel('epoch')
# plt.legend(['train', 'val'], loc='upper left')
# plt.show()
#
# plt.plot(history2.history['Tversky'])
# plt.plot(history2.history['val_Tversky'])
# plt.title('model tversky')
# plt.ylabel('Tversky')
# plt.xlabel('epoch')
# plt.legend(['train', 'val'], loc='upper left')
# plt.show()

# %%
import os
os._exit(00)

# %% [raw]
# x, y = Valid_Images[500:507], Valid_Masks[500:507]
# preds = adversarial_model.predict_on_batch(x)[0]
# visualize(x,y, pred_batch = preds, num_samples=7)

# %%
# x_train,y_train = next(train_generator)
# generator.fit(x_train,y_train, epochs = 100, validation_data=[Valid_Image,Valid_Mask], batch_size = 8)

# %%
print(lr)

# %% [raw]
# val =  generator.evaluate(Valid_Images, Valid_Masks, batch_size = 8, verbose = 1)

# %% [raw]
# generator.save_weights("{}/gen_UNET_NRC2D_SEP_{}_{} P_ {} R.h5".format(directory,Version, val[4], val[5]))
# adversarial_model.save_weights("{}/adv_UNET_NRC2D_SEP_{}_{} P_ {} R.h5".format(directory, Version, val[4], val[5]))
# discriminator.save_weights("{}/dis_UNET_NRC2D_SEP_{}_{} P_ {} R.h5".format(directory, Version, val[4], val[5]))

# %% [raw]
# for i in range(32):
#     print(batch_x[7][ :, :, i].shape)
#     plt.imshow(batch_y[7][:, :, i].reshape(ph,pw), cmap="gray")
#     plt.show()
#     print(batch_y[7][ :, :, i].shape)
#     plt.imshow(batch_x[7][:, :, i].reshape(ph,pw), cmap="gray")
#     plt.show()

# %% [raw]
# Test_Image = process_image_scan("Dataset - Copy backup/VALID/Image/training01_04_flair_pp.nii",h,w,d,0)
# Test_Mask = process_mask_scan("Dataset - Copy backup/VALID/Mask2/training01_04_mask2.nii",h,w,d,0)

# %% [raw]
# n = get_patches(Test_Image,h,w,d,ph,pw,pd,c)
# P = generator.predict(n, batch_size = 4)
# recon = recnstruct_patches(P,h,w,d,ph,pw,pd,c).numpy()

# %% [raw]
# import matplotlib.pyplot as plt
# for i in range(256):
#     print(recon[ :, :, i].shape)
#     plt.imshow(recon[:, :, i].reshape(h,w), cmap="gray")
#     plt.show()

# %% [raw]
# j=0
# target_x = 256
# target_y = 256
# for i in range(256):
#     """
#     plt.imshow(i[0].reshape(512,256,3))
#     plt.show()
#     plt.imshow(prediction[0].reshape(512,256))
#     plt.show()
#
#     plt.imsave("Saved SEG/image_{}.jpeg".format(j), i[0].reshape(512,256,3))
#     plt.imsave("Saved SEG/mask_{}.jpeg".format(j), i[1].reshape(512,256))
#     plt.imsave("Saved SEG/prediction_{}.jpeg".format(j), prediction[0].reshape(512,256))
#     """
#     E = np.ones((target_x,25,3))
#     imgs = [np.stack(((Test_Image[:,:,i]*255).astype("uint8"),)*3, axis=-1).reshape(target_x,target_y,3),E*255,
#             np.stack(((Test_Mask[:,:,i]*255).astype("uint8"),)*3, axis=-1).reshape(target_x,target_y,3),E*255,
#             np.stack(((recon[: ,: ,i]*255).astype("uint8"),)*3, axis=-1).reshape(target_x,target_y,3)]
#     total_width = target_x*3
#     max_height = target_y
#     imgs_comb = np.hstack( (i for i in imgs ) ).astype("uint8")
#     plt.imshow(imgs_comb)
#     plt.show()
#     plt.imsave('Saved Seg 2D_2/IM{}.jpg'.format(j),imgs_comb)
#     j+=1

# %% [raw]
# # generator.save_weights("Segmentation GAN WEIGHTS/gen_UNET_NRC2D_V4.h5")
# # adversarial_model.save_weights("Segmentation GAN WEIGHTS/adv_UNET_NRC2D_V4.h5")
# # discriminator.save_weights("Segmentation GAN WEIGHTS/dis_UNET_NRC2D_V4.h5")

# %% [raw]
# Test_Image = np.array(process_image_scan("KASMI-SOULEF.to-double.nii", h, w, d, 0))
# print(Test_Image.shape)

# %% [raw]
# n = get_patches(Test_Image,h,w,d,ph,pw,pd,c)
# P = generator.predict(n, batch_size = 1)
# recon = recnstruct_patches(P,h,w,d,ph,pw,pd,c).numpy()

# %% [raw]
# import matplotlib.pyplot as plt
# for i in range(256):
#     print(recon[ :, :, i].shape)
#     plt.imshow(recon[:, :, i].reshape(h,w), cmap="gray")
#     plt.show()

# %%
def apply_mask_color(mask, mask_color):
    return np.concatenate(([mask[ ... , np.newaxis] * color for color in mask_color]), axis=2)

# %%
mask_color = np.array([128, 0, 0])

# %% [raw]
# j=0
# target_x = 256
# target_y = 256
# for i in range(256):
#     """
#     plt.imshow(i[0].reshape(512,256,3))
#     plt.show()
#     plt.imshow(prediction[0].reshape(512,256))
#     plt.show()
#
#     plt.imsave("Saved SEG/image_{}.jpeg".format(j), i[0].reshape(512,256,3))
#     plt.imsave("Saved SEG/mask_{}.jpeg".format(j), i[1].reshape(512,256))
#     plt.imsave("Saved SEG/prediction_{}.jpeg".format(j), prediction[0].reshape(512,256))
#     """
#     E = np.ones((target_x,25,3))
#     imgs = [np.stack(((Test_Image[:,:,i]*255).astype("uint8"),)*3, axis=-1).reshape(target_x,target_y,3),E*255,
#             np.stack(((recon[: ,: ,i]*255).astype("uint8"),)*3, axis=-1).reshape(target_x,target_y,3)]
#     total_width = target_x*2
#     max_height = target_y
#     imgs_comb = np.hstack( (i for i in imgs ) ).astype("uint8")
#     plt.imshow(imgs_comb)
#     plt.show()
#     plt.imsave('Saved Seg 2D_3/IM{}.jpg'.format(j),imgs_comb)
#     j+=1

# %% [raw]
# from PIL import Image
# import cv2
# pathh = "Generated VAL Images"
# for i in range(len(y_test)):
#     A = x_test[i].reshape(256,256)
#     #plt.imshow(A, cmap="gray")
#     #plt.show()
#     B = generator.predict(A.reshape(1,256,256,1)).reshape(256,256)
#     A = np.stack((A,)*3, axis=-1)
#     B = apply_mask_color(B, mask_color)/255
#     #plt.imshow(B)
#     #plt.show()
#     H = A * 0.5 + B*0.9
#
#     #plt.imsave(pathh+"/val_generated_image_{}.png".format(i),H)
#     plt.imshow(H)
#     plt.show()

# %%
# np.save("Train_Images.npy", Train_Image)
# np.save("Train_Masks.npy", Train_Mask.astype("uint8"))
# np.save("Valid_Images.npy", Valid_Image)
# np.save("Valid_Masks.npy", Valid_Mask.astype("uint8"))

# %% [raw]
# for i in range(256):
#     print(recon[ :, :, i].shape)
#     plt.imshow(recon[:, :, i].reshape(h,w), cmap="gray")
#     plt.show()
